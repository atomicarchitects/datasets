# %%
from atomic_datasets.datasets import QM9
from atomic_datasets.wrappers.jax import JraphDataset

# %%
dataset = QM9(root_dir="data/")
dataset = JraphDataset(dataset)
# Out:
# Loading QM9 from cache: /home/daigavaa/datasets/examples/data/qm9/qm9_preprocessed_False.npz
# Loaded 133885 molecules from cache
# Dataset description available at: /home/daigavaa/datasets/examples/data/qm9/QM9_README

# %%
print(len(dataset))
# Out:
# 133885

# %%
for graph in dataset:
    print(graph)
    break
# Out:
# WARNING:2026-02-10 00:11:36,119:jax._src.xla_bridge:876: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# GraphsTuple(nodes={'positions': Array([[-1.2700e-02,  1.0858e+00,  8.0000e-03],
#        [ 2.2000e-03, -6.0000e-03,  2.0000e-03],
#        [ 1.0117e+00,  1.4638e+00,  3.0000e-04],
#        [-5.4080e-01,  1.4475e+00, -8.7660e-01],
#        [-5.2380e-01,  1.4379e+00,  9.0640e-01]], dtype=float32), 'species': Array([1, 0, 0, 0, 0], dtype=int32), 'atomic_numbers': Array([6, 1, 1, 1, 1], dtype=int32), 'atom_types': ['C', 'H', 'H', 'H', 'H']}, edges=None, receivers=Array([], shape=(0,), dtype=int32), senders=Array([], shape=(0,), dtype=int32), globals=None, n_node=Array([5], dtype=int32), n_edge=Array([0], dtype=int32))
